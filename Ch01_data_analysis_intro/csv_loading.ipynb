# %%
import gdown    #구글 드라이브 다운 패키지
import chardet  #인코딩 방식 확인 패키지
import pandas as pd

# gdown.download('https://bit.ly/3eecMKZ', '남산도서관 장서 대출목록 (2021년 04월).csv', quiet=False)
# ㄴgoogle drive에서 링크를 통해 파일 다운

# df = pd.read_csv('남산도서관 장서 대출목록 (2021년 04월).csv', encoding='EUC-KR')
'''
read_csv : pandas에서 csv 파일을 읽을 때 사용하는 함수
output >> DtypeWarning: Columns (0: ISBN, 1: 세트 ISBN, 2: 주제분류번호) have mixed types.
    ㄴ>> pandas는 메모리 효율을 위해 csv파일을 나눠 읽음 > 자동파악한 데이터 type 다르면 warning
'''

df =pd.read_csv('남산도서관 장서 대출목록 (2021년 04월).csv', encoding='EUC-KR', low_memory=False)
#       ㄴ low_memory 매개변수 = False 지정하여 pandas가 데이터 자동파악 방지, 한 번에 읽음

df.head()   #첫 dataframe의 5개 행 확인
df.to_csv('ns_202104.csv')  #data frame > csv file save

# ns_df = pd.read_csv('ns_202104.csv', low_memory=False)  #csv > data frame
#  ㄴ ns_df.head()  :  #index 생성되며 'Unnamed:0' 이라는 첫 번째 열과 중복됨


ns_df = pd.read_csv('ns_202104.csv', index_col = 0, low_memory=False)   
#   ㄴ index_col : csv file에 인덱스가 있음을 알려줌 > 중복 열 제거
ns_df.head()
'''
or 다른 방식 vv
df.to_csv('ns_202104.csv', index = False)
  ㄴindex 매개변수 False 지정하여 중복 제거
'''

# with open('ns_202104.csv', encoding = 'UTF-8') as f:  > 텍스트 파일은 open() 함수로 열 수 있음
#     for i in range(3):
#         print(f.readline(), end='')
# Out:
#    번호                    도서명                저자    출판사  발행년도           ISBN  \
# 0   1                인공지능과 흙            김동훈 지음    민음사  2021  9788937444319
# 1   2           가짜 행복 권하는 사회            김태형 지음   갈매나무  2021  9791190123969
# 2   3  나도 한 문장 잘 쓰면 바랄 게 없겠네            김선영 지음   블랙피쉬  2021  9788968332982
# 3   4                예루살렘 해변  이도 게펜 지음, 임재희 옮김  문학세계사  2021  9788970759906
# 4   5  김성곤의 중국한시기행 : 장강·황하 편            김성곤 지음    김영사  2021  9788934990833
#
#   세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자  Unnamed: 13
# 0     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN
# 1     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN
# 2     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN
# 3     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN
# 4     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN

# %% [markdown]
# 2026.03.11
#
# #TODO : CSV 파일 가져와서 읽고 저장하기
#
# 1. gdown() 함수를 이용하여 google drive에서 파일 다운
# 2. pandas 패키지 모듈 중 하나인 read_csv를 이용하여 csv 파일을 읽음
# 3. read_csv에서 pandas는 메모리 절약을 위해 csv파일을 나눠 읽는데,
#    이때 자동으로 파악한 data가 다르면 Dtype Warning 발생 >> low_memory 사용하여 데이터 자동파악 대신 한 번에 파일 읽음
#
# 4. 이때 가져온 csv파일의 중요 부분만 확인하기 위해 head() 함수 사용하여 data frame의 첫 5개의 행 확인
#    >>to_csv 이용하여 data frame을 csv 파일로 저장함
#
# 5. csv 파일에 index가 존재 >> index_col = 0 지정하여 index 중복 열 제거
#    >> or 가져온 파일을 csv파일로 변경 시 to_csv('...', index = False) 지정하여 index 매개변수 중복 열 제거 가능
