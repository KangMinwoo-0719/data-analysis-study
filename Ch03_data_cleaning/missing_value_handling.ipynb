# %%
import gdown

gdown.download('https://bit.ly/3GisL6J', 'ns_book4.csv', quiet=False)
# Out:
# c:\Users\pili4\python-data-analysis-study\venv\Lib\site-packages\requests\__init__.py:113: RequestsDependencyWarning: urllib3 (2.6.3) or chardet (7.0.1)/charset_normalizer (3.4.5) doesn't match a supported version!
#   warnings.warn(
# Downloading...
# From: https://bit.ly/3GisL6J
# To: c:\Users\pili4\python-data-analysis-study\Ch03_data_cleaning\ns_book4.csv
# 100%|██████████| 55.5M/55.5M [00:02<00:00, 19.8MB/s]
# 'ns_book4.csv'
